# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import nltk
import warnings
warnings.filterwarnings(action="ignore")

# %% [markdown]
# ### Load the dataset

# %%
df= pd.read_csv("IMDB_movie_review_dataset.csv")

# %% [markdown]
# ### Understand the Dataset

# %%
df.head()
# Out:
#     movie_id  movie_rating review_username  review_rating  \
# 0  tt9531772           5.9       MuviFan73            5.0
# 1  tt9531772           5.9       sndpkumar            5.0
# 2  tt9531772           5.9   imaryan-79408            6.0
# 3  tt9531772           5.9           winak            3.0
# 4  tt9531772           5.9    vitthalmisal           10.0
#
#                                         review_title  \
# 0  Not as good as Rohits previous movies, seems d...
# 1                  Pathetic screenplay and dialogues
# 2                        isse acha singham dekh leta
# 3                Garbage that needs to be canned !!!
# 4              Well made blockbuster by rohit Shetty
#
#                                 review_detailed_main    movie_name
# 0  Story: During 93 Mumbai blasts 400kg RDX was u...  Sooryavanshi
# 1  The dialogues and screenplay are too cliche. C...  Sooryavanshi
# 2  Movie lose it's pace and cringe jokes are also...  Sooryavanshi
# 3  I am amazed that in this day and age of the "e...  Sooryavanshi
# 4  A bit lengthy but well made movie epic blockbu...  Sooryavanshi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131926 entries, 0 to 131925
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   movie_id              131926 non-null  object
#  1   movie_rating          131926 non-null  float64
#  2   review_username       131926 non-null  object
#  3   review_rating         122632 non-null  float64
#  4   review_title          131924 non-null  object
#  5   review_detailed_main  97377 non-null   object
#  6   movie_name            131926 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 7.0+ MB

# %%
df.describe()
# Out:
#         movie_rating  review_rating
# count  131926.000000  122632.000000
# mean        5.336358       5.475969
# std         2.268431       3.516962
# min         1.200000       1.000000
# 25%         3.300000       1.000000
# 50%         5.300000       6.000000
# 75%         8.000000       9.000000
# max         9.300000      10.000000

# %%
df.shape
# Out:
# (131926, 7)

# %% [markdown]
# ### Check for Missing Values
# - Identify missing values:

# %%
df.isnull().sum()
# Out:
# movie_id                    0
# movie_rating                0
# review_username             0
# review_rating            9294
# review_title                2
# review_detailed_main    34549
# movie_name                  0
# dtype: int64

# %% [markdown]
# - Drop rows with missing text

# %%
df.dropna(subset=["review_rating","review_title"],inplace=True)

# %%
df.isnull().sum()
# Out:
# movie_id                    0
# movie_rating                0
# review_username             0
# review_rating               0
# review_title                0
# review_detailed_main    25255
# movie_name                  0
# dtype: int64

# %% [markdown]
# - Add review columns

# %%
df['review']= df["review_title"] + df["review_detailed_main"]

# %%
df.isnull().sum()
# Out:
# movie_id                    0
# movie_rating                0
# review_username             0
# review_rating               0
# review_title                0
# review_detailed_main    25255
# movie_name                  0
# review                  25255
# dtype: int64

# %%
df['review'] = df['review'].fillna(df['review_title'])

# %%
df.drop(columns=["review_title","review_detailed_main"],inplace=True)

# %%
df.isnull().sum()
# Out:
# movie_id           0
# movie_rating       0
# review_username    0
# review_rating      0
# movie_name         0
# review             0
# dtype: int64

# %% [markdown]
# ### Check for Duplicates

# %%
print(df.duplicated().sum())
# Out:
# 15750

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (106880, 6)

# %% [markdown]
# ### Add Sentiment Column

# %%
def add_sentiment(rating):
    if rating >= 8:
        return "positive"
    elif rating >= 5:
        return "neutral"
    else:
        return "negative"

df['sentiment'] = df['review_rating'].apply(add_sentiment)

# %%
df.head()
# Out:
#     movie_id  movie_rating review_username  review_rating    movie_name  \
# 0  tt9531772           5.9       MuviFan73            5.0  Sooryavanshi
# 1  tt9531772           5.9       sndpkumar            5.0  Sooryavanshi
# 2  tt9531772           5.9   imaryan-79408            6.0  Sooryavanshi
# 3  tt9531772           5.9           winak            3.0  Sooryavanshi
# 4  tt9531772           5.9    vitthalmisal           10.0  Sooryavanshi
#
#                                               review sentiment
# 0  Not as good as Rohits previous movies, seems d...   neutral
# 1  Pathetic screenplay and dialoguesThe dialogues...   neutral
# 2  isse acha singham dekh letaMovie lose it's pac...   neutral
# 3  Garbage that needs to be canned !!!I am amazed...  negative
# 4  Well made blockbuster by rohit ShettyA bit len...  positive

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    41905
# negative    40821
# neutral     24154
# Name: count, dtype: int64

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Analyze Sentiment Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# sns.countplot(x='sentiment', data=df,palette="pastel")
sentiment_counts = df['sentiment'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(sentiment_counts,labels=sentiment_counts.index, autopct='%1.1f%%',colors = ['#FF6347', '#FFD700', '#90EE90'])
plt.title("Sentiment Distribution")
plt.show()

# %% [markdown]
# #### Analyze Top movies by sentiment

# %%
positive_reviews = df[df['sentiment'] == 'positive']
#print(positive_reviews)

positive_reviews_count = positive_reviews['movie_name'].value_counts().head(10)
#print(positive_reviews_count)

plt.figure(figsize=(10, 6))
sns.barplot(x=positive_reviews_count.values, y=positive_reviews_count.index,palette='crest' )
plt.title('Top 10 Movies by Positive Sentiment')
plt.xlabel('Number of Positive Reviews')
plt.ylabel('Movie Name')
plt.show()

# %% [markdown]
# #### Analyze average review rating by movies

# %%
average_rating = df.groupby('movie_name')['review_rating'].mean().sort_values(ascending=True).head(10)
#print(average_rating)
plt.figure(figsize=(10, 6))
sns.barplot(x=average_rating.values, y=average_rating.index, palette='viridis')
plt.title('Average Rating by Movie')
plt.xlabel('Average Review Rating')
plt.ylabel('Movie Name')
plt.show()

# %% [markdown]
# #### Analyze Review rating by sentiment

# %%
sns.boxplot(x='sentiment', y='review_rating', data=df, palette='coolwarm')
plt.title("Review Rating by Sentiment")
plt.xlabel('Sentiment')
plt.ylabel('Review Rating')
plt.show()

# %% [markdown]
# #### Word Cloud

# %%
from wordcloud import WordCloud

# Generate a word cloud for positive reviews
positive_reviews = ' '.join(df[df['sentiment'] == 'positive']['review'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common Words in Positive Reviews")
plt.show()

# %% [markdown]
# ### Feature Selection

# %%
df= df[["review","sentiment"]]

# %%
df.head()
# Out:
#                                               review sentiment
# 0  Not as good as Rohits previous movies, seems d...   neutral
# 1  Pathetic screenplay and dialoguesThe dialogues...   neutral
# 2  isse acha singham dekh letaMovie lose it's pac...   neutral
# 3  Garbage that needs to be canned !!!I am amazed...  negative
# 4  Well made blockbuster by rohit ShettyA bit len...  positive

# %% [markdown]
# ### Label encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder =LabelEncoder()
df["sentiment"]= encoder.fit_transform(df["sentiment"])
df.head()
# Out:
#                                               review  sentiment
# 0  Not as good as Rohits previous movies, seems d...          1
# 1  Pathetic screenplay and dialoguesThe dialogues...          1
# 2  isse acha singham dekh letaMovie lose it's pac...          1
# 3  Garbage that needs to be canned !!!I am amazed...          0
# 4  Well made blockbuster by rohit ShettyA bit len...          2

# %%
# Save the label encoder
import pickle
with open("label_encoder.pkl", "wb") as encoder_file:
    pickle.dump(encoder, encoder_file)

# %% [markdown]
# ### Preprocessing for NLP

# %% [markdown]
# #### build vocabulary

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

stopwords_to_remove=stopwords.words('english')
# stopwords_to_remove=set(stopwords_to_remove)

#lemmatization object creation
lemmatizer = WordNetLemmatizer()

# empty vocabulary to store all  the values
vocabulary=[]

cnt=1
for review in df["review"]:

    #Sentence Tokenization
    sentences= nltk.sent_tokenize(review)

    for sentence in sentences:
        # print("\n===================\n")
        # print(sentence)
        sentence = sentence.lower()
        sentence = re.sub(r'[^a-zA-Z\s]', '', sentence)
        # print("\n---------------\n")

        # word tokenization
        words= nltk.word_tokenize(sentence)

        #removing stop words and lemmatiation
        words=[ lemmatizer.lemmatize(word.strip()) for word in words if word.strip() not in stopwords_to_remove]

        # Adding word to vocabulary where all words will be kept
        vocabulary.extend([ word for word in words])

 # print(cnt)
cnt+=1

vocabulary = list(set(vocabulary))
len(vocabulary)
# Out:
# 187251

# %%
# get all reviews
reviews = [review.lower() for review in df['review']]

# %% [markdown]
# #### Vectorization
# - convert text into numerical form:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# create a vectorizer
vectorizer = TfidfVectorizer(vocabulary=vocabulary)

# convert the input reviews to numeric format
vectorizer.fit(reviews)
# Out:
# TfidfVectorizer(vocabulary=['herher', 'everask', 'ithilarious', 'substance',
#                             'shatner', 'overrall', 'timesrebel', 'skinshowing',
#                             'bitty', 'youthcriticism', 'betteractor',
#                             'goodmustwatchmovie', 'allhuman', 'dramarom',
#                             'crackin', 'khnh', 'godsakes', 'supremely',
#                             'naatak', 'nondigitized',
#                             'picturizationschoreography', 'andromeda',
#                             'gorefestthis', 'lolls', 'allconquering', 'isand',
#                             'communistrelated', 'mendelshon', 'communalism',
#                             'oneive', ...])

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['herher', 'everask', 'ithilarious', ..., 'jist', 'everfaithful',
#        'delightfulthe'], dtype=object)

# %%
# Save the vectorizer
with open("tfidf_vectorizer.pkl", "wb") as vectorizer_file:
    pickle.dump(vectorizer, vectorizer_file)

# %% [markdown]
# ### Build the Model
# ####  split the data into x and y

# %%
x = vectorizer.transform(reviews)
y = df['sentiment']

# %%
x[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 81 stored elements and shape (1, 187251)>

# %% [markdown]
# #### split the data into train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=123456)

# %% [markdown]
# #### train the model

# %% [markdown]
# ##### using logistic regression

# %%
from sklearn.linear_model import LogisticRegression
model_lg = LogisticRegression(max_iter=1000)
model_lg.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# #### Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
y_pred = model_lg.predict(x_test)
y_true = y_test

# %%
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred,average='macro')
recall = recall_score(y_true, y_pred,average='weighted')
f1 = f1_score(y_true, y_pred,average='micro')

print(f"accuray = {accuracy}")
print(f"precision = {precision}")
print(f"recall = {recall}")
print(f"f1 = {f1}")
# Out:
# accuray = 0.7601671656686627
# precision = 0.7296562570277455
# recall = 0.7601671656686627
# f1 = 0.7601671656686627

# %%
print("Training Accuracy :", model_lg.score(x_train, y_train))
print("Testing Accuracy :", model_lg.score(x_test, y_test))

# %% [markdown]
# #### Save the Model

# %%
with open("model_logistic.pkl", "wb") as model_file:
    pickle.dump(model, model_file)

# %% [markdown]
# #### Using Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
y_pred = model.predict(x_test)
y_true = y_test

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred,average='macro')
recall = recall_score(y_true, y_pred,average='weighted')
f1 = f1_score(y_true, y_pred,average='micro')

print(f"accuray = {accuracy}")
print(f"precision = {precision}")
print(f"recall = {recall}")
print(f"f1 = {f1}")
# Out:
# accuray = 0.6926771457085829
# precision = 0.7140049184778983
# recall = 0.6926771457085829
# f1 = 0.6926771457085829

# %% [markdown]
# #### Using XGB Boost

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier()
model_xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
y_pred = model_xgb.predict(x_test)
y_true = y_test

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred,average='macro')
recall = recall_score(y_true, y_pred,average='weighted')
f1 = f1_score(y_true, y_pred,average='micro')

print(f"accuray = {accuracy}")
print(f"precision = {precision}")
print(f"recall = {recall}")
print(f"f1 = {f1}")
# Out:
# accuray = 0.7219935129740519
# precision = 0.6944874987814152
# recall = 0.7219935129740519
# f1 = 0.7219935129740519

# %%
# Save the trained model
with open('model_xgb.pkl', 'wb') as file:
    pickle.dump(model_xgb, file)
